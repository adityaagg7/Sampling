# %%
# define the dataset location
import pandas as pd
filename = "data.csv"
# load the csv file as a data frame
dataset = pd.read_csv(filename)

# %%
# class count
class_count_0, class_count_1 = dataset['Class'].value_counts()

# Separate class
class_0 = dataset[dataset['Class'] == 0]
class_1 = dataset[dataset['Class'] == 1]# print the shape of the class
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (763, 31)
# class 1: (9, 31)

# %%
class_1_over = class_1.sample(class_count_0, replace=True)

test_over = pd.concat([class_1_over, class_0], axis=0)

print("total class of 1 and 0:",test_over['Class'].value_counts())# plot the count after under-sampeling
test_over['Class'].value_counts().plot(kind='bar', title='count (target)')
# Out:
# total class of 1 and 0: 1    763
# 0    763
# Name: Class, dtype: int64
# <AxesSubplot: title={'center': 'count (target)'}>

# %%
test_over
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 182   118  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 244   164  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480
# 699   529 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262
# 699   529 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262
# ..    ...       ...       ...       ...       ...       ...       ...
# 767   575 -0.572263  0.731748  1.541254  0.150506  1.108974  0.372152
# 768   579 -1.296845 -0.511605  2.404726 -0.310762 -0.319551 -0.542842
# 769   579  1.214170  0.210481  0.484651  0.479768 -0.261955 -0.527039
# 770   580  1.267030 -0.071114  0.037680  0.512683  0.242392  0.705212
# 771   581  1.153758  0.132273  0.382969  1.405063 -0.224287 -0.197295
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
# class count
class_count_0, class_count_1 = dataset['Class'].value_counts()

# Separate class
class_0 = test_over[test_over['Class'] == 0]
class_1 = test_over[test_over['Class'] == 1]# print the shape of the class
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (763, 31)
# class 1: (763, 31)

# %%
#sample size
z=1.96
p=0.5
e=0.05
n = (z**2*p*(1-p))/(e**2)
n
# Out:
# 384.1599999999999

# %%
n=384

# %%
sample1 = test_over.sample(n)

# %%
sample1
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 101    68 -0.770196  0.483572  1.901072 -0.001876  0.024245 -1.171903
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 688   519  0.764614  1.706191 -1.755823  1.557386  1.101083 -1.529455
# 668   508  1.335369  0.535982 -0.448156  0.902998  0.517134 -0.694213
# ..    ...       ...       ...       ...       ...       ...       ...
# 170   108  1.206065 -0.124885  0.118939  0.023735 -0.549087 -0.949920
# 717   539 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788
# 408   294 -0.745116  0.446440  1.714154 -0.146626 -0.244287 -0.963058
# 756   564 -0.203837  0.532747 -0.339857 -0.730934  2.728163  3.535882
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
import numpy as np
def systematic_sampling(test_over, step):
 
    indexes = np.arange(0, len(test_over), step=step)
    sample2 = test_over.iloc[indexes]
    return sample2
 
 
# Obtain a systematic sample and save it in a new variable
N = 1526
n = 384
step = int(N/n)
sample2 = systematic_sampling(test_over, step)
display(sample2)
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 182   118  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256
# 699   529 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 717   539 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788
# 244   164  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480
# ..    ...       ...       ...       ...       ...       ...       ...
# 757   566  1.166360  0.005061  0.497768  0.798920 -0.365524 -0.233421
# 760   571 -2.355336  2.316182  0.701735  0.174501  0.677346  1.029705
# 763   574 -0.402057  0.584300  2.474227  0.929684  0.014314  0.297490
# 767   575 -0.572263  0.731748  1.541254  0.150506  1.108974  0.372152
# 770   580  1.267030 -0.071114  0.037680  0.512683  0.242392  0.705212
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
1
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   204 -0.188424  0.877602 -0.734686 -0.913404  1.941770  4.037423 -1.707118
# 1   472  1.017055 -0.185049  1.181666  1.073490 -0.550586  0.971827 -0.806452
# 2   484 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 3   574  1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481  0.094272
# 0   442 -0.753360  0.547357  0.632550 -1.728280  0.937092 -1.065111  1.511596
# 1   365 -0.456586  0.541708  1.331297  0.559447  0.184045  0.612792  0.632759
# 2   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 3   539 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0 -2.537641 -0.590338  ... -1.042331  0.168265  0.963855  0.887850  0.171167
# 1  0.484792  0.517268  ...  0.875848 -0.053458 -0.269918  0.328907 -0.217332
# ...
